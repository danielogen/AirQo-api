# %%
import pandas as pd
import numpy as np

import os

import datetime as dt
from datetime import datetime,timedelta
from pytz import all_timezones

import json, requests
import pickle
import OpenSSL

from pymongo import MongoClient

# %%
def connect_mongo(db, host='localhost', port=27017, ):
    """ A util for making a connection to mongo """

    conn = MongoClient(host, port)
    return conn[db]

# %%
def read_mongo(db, collection, query={}, host='localhost', port=27017, no_id=True):
    """ Read from Mongo and Store into DataFrame """

    # Connect to MongoDB
    db = connect_mongo(host=host, port=port, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query)

    # Expand the cursor and construct the DataFrame
    df =  pd.DataFrame(list(cursor))
    
    return df

# %%
metadata_df =read_mongo('channel_db', 'metadata_coll')

# %%
channel_ids = metadata_df['channel_id']
channel_keys = metadata_df['read_api_key']
channel_dict = dict(zip(channel_ids, channel_keys))

# %%
#function that downloads all channel data form ThingSpeak
def download(apiurl,cache='use',verbose=False,apikey=None,cacheonly=None):
    """
    download(apiurl,cache='use',verbose=False,apikey=None):
    Loads thingspeak data from apiurl
    Set cache to:
        'use' - to use it
        'refresh' - to not use it
        'only' - to only use it
    cacheonly = if set, only cache this many previous training points,
       will only report this many when output. This is useful to avoid
       caches becoming arbitrarily large with historic data.
    """
    filename = 'channel%s.p'%apiurl.split('/')[-1]
    cachefile = os.path.isfile(filename)
    if (cache=='use' or cache=='only') and cachefile:
        alldata = pickle.load( open( filename, "rb" ) )
        if (cache=='only'):
            if verbose: print("Using just cache - may be out of date")
            return alldata
        if verbose: print("Using cache")
        nextid = alldata[-1]['entry_id']+1
        endtime = str_to_date(alldata[-1]['created_at'])+timedelta(seconds=1)
    else: #no cachefile or refresh -> we want to reload from the API
        if verbose: print("Ignoring/overwriting cache")
        if (cache=='only'):
            ##TODO Throw exception - can't only use cache as there is no cache
            assert False, "Can't only use cache as there is no cache"
        nextid = 1
        alldata = []
        endtime = None  
    if (cache=='only'): #we should stop now, and use the cached data we've got
        return alldata
        
    result = None
    if verbose: print("Using %d records from cache" % len(alldata))
    while result != -1:
        #thingspeak doesn't let you download ranges of ids, instead you have to
        #download ranges of dates. We can only download 8000 at a time, so we
        #need to get the date of the next one we need (then we ask for that datetime
        #until now, and repeat until we run out of new items).
        url = apiurl+'/feeds/entry/%d.json' % (nextid)
        if apikey is not None: url += '?api_key=%s' % apikey
        print("Loading from %s" % url)
        result = json.loads(requests.post(url, timeout = 100.0).content.decode('utf-8'))
        starttime = endtime
        if result==-1:
            #if verbose: print("Warning: Unable to retrieve data (does channel exist? is it public?)")
            endtime = datetime.now()
        else:
            endtime = str_to_date(result['created_at'])
        if (nextid==1):
            starttime = endtime
        else:
            start = datetime.strftime(starttime,'%Y-%m-%dT%H:%M:%SZ')
            end = datetime.strftime(endtime-timedelta(seconds=1),'%Y-%m-%dT%H:%M:%SZ')
            url = apiurl+'/feeds.json?start=%s&end=%s' % (start,end)
            if apikey is not None: url += '&api_key=%s' % apikey
            print("Loading from %s" % url)                        
            data = json.loads(requests.post(url, timeout = 100.0).content.decode('utf-8'))
            if (data!=-1):
                alldata.extend(data['feeds'])
                if verbose: print("    Adding %d records..." % len(data['feeds']))
            else:
                if verbose: print("Warning: unable to read data feed")
            
        nextid += 7999 #thought download was 8000 fields, but it's 8000 records. 8000/len(result)
    if verbose: print("New cache has %d records, saving." % len(alldata))
    
    if cacheonly is not None:
        pickle.dump( alldata[-cacheonly:], open( filename, "wb" ) )
    else:
        pickle.dump( alldata, open( filename, "wb" ) )
    return alldata

# %%
#Function that converts a string to datetime format
def str_to_date(st):
    return datetime.strptime(st,'%Y-%m-%dT%H:%M:%SZ')

# %%
channel_data_list = []
for channel_id, channel_key in channel_dict.items():
    channel_url = 'http://thingspeak.com/channels/'+str(channel_id)
    data = download(channel_url, verbose = True, apikey = channel_key)
    
    df = pd.DataFrame(data)#creating a dataframe of the data
    
    df['created_at'] =  pd.to_datetime(df['created_at']) #converting to DateTime format
    df['created_at'] = df['created_at'].dt.tz_convert('Africa/Kampala') #Converting from UTC to EAT
    
    df['channel_id'] = channel_id #adding an additional column
    print(channel_id, ":done!")
    channel_data_list.append(df)
# Out:
# Using cache
# Using 76984 records from cache
# Loading from http://thingspeak.com/channels/643676/feeds/entry/76985.json?api_key=MXMFGRF4ERL4VKI2
# Loading from http://thingspeak.com/channels/643676/feeds.json?start=2019-06-23T20:43:37Z&end=2019-10-11T20:02:38Z&api_key=MXMFGRF4ERL4VKI2
#     Adding 0 records...
# New cache has 76984 records, saving.
# 643676 :done!
# Using cache
# Using 165977 records from cache
# Loading from http://thingspeak.com/channels/667402/feeds/entry/165978.json?api_key=A7E6OGD6QRIAVVK7
# Loading from http://thingspeak.com/channels/667402/feeds.json?start=2019-10-11T11:42:42Z&end=2019-10-11T11:43:20Z&api_key=A7E6OGD6QRIAVVK7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/667402/feeds/entry/173977.json?api_key=A7E6OGD6QRIAVVK7
# Loading from http://thingspeak.com/channels/667402/feeds.json?start=2019-10-11T11:43:21Z&end=2019-10-11T20:02:48Z&api_key=A7E6OGD6QRIAVVK7
#     Adding 137 records...
# New cache has 166114 records, saving.
# 667402 :done!
# Using cache
# Using 118631 records from cache
# Loading from http://thingspeak.com/channels/667406/feeds/entry/118632.json?api_key=1K40QAHJQLR3R6HB
# Loading from http://thingspeak.com/channels/667406/feeds.json?start=2019-10-11T11:43:11Z&end=2019-10-11T11:43:44Z&api_key=1K40QAHJQLR3R6HB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/667406/feeds/entry/126631.json?api_key=1K40QAHJQLR3R6HB
# Loading from http://thingspeak.com/channels/667406/feeds.json?start=2019-10-11T11:43:45Z&end=2019-10-11T20:03:00Z&api_key=1K40QAHJQLR3R6HB
#     Adding 221 records...
# New cache has 118852 records, saving.
# 667406 :done!
# Using cache
# Using 77863 records from cache
# Loading from http://thingspeak.com/channels/672528/feeds/entry/77864.json?api_key=YOW5ITSXCLW7IA0C
# Loading from http://thingspeak.com/channels/672528/feeds.json?start=2019-10-11T11:42:55Z&end=2019-10-11T11:44:15Z&api_key=YOW5ITSXCLW7IA0C
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/672528/feeds/entry/85863.json?api_key=YOW5ITSXCLW7IA0C
# Loading from http://thingspeak.com/channels/672528/feeds.json?start=2019-10-11T11:44:16Z&end=2019-10-11T20:03:10Z&api_key=YOW5ITSXCLW7IA0C
#     Adding 152 records...
# New cache has 78015 records, saving.
# 672528 :done!
# Using cache
# Using 196378 records from cache
# Loading from http://thingspeak.com/channels/675740/feeds/entry/196379.json?api_key=H3EY1WFQK4M2C2ZP
# Loading from http://thingspeak.com/channels/675740/feeds.json?start=2019-10-11T11:42:50Z&end=2019-10-11T11:44:04Z&api_key=H3EY1WFQK4M2C2ZP
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675740/feeds/entry/204378.json?api_key=H3EY1WFQK4M2C2ZP
# Loading from http://thingspeak.com/channels/675740/feeds.json?start=2019-10-11T11:44:05Z&end=2019-10-11T20:03:21Z&api_key=H3EY1WFQK4M2C2ZP
#     Adding 245 records...
# New cache has 196623 records, saving.
# 675740 :done!
# Using cache
# Using 215694 records from cache
# Loading from http://thingspeak.com/channels/675801/feeds/entry/215695.json?api_key=0T0B4DV3ZXBIGF7L
# Loading from http://thingspeak.com/channels/675801/feeds.json?start=2019-10-11T11:43:58Z&end=2019-10-11T11:45:26Z&api_key=0T0B4DV3ZXBIGF7L
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675801/feeds/entry/223694.json?api_key=0T0B4DV3ZXBIGF7L
# Loading from http://thingspeak.com/channels/675801/feeds.json?start=2019-10-11T11:45:27Z&end=2019-10-11T20:03:37Z&api_key=0T0B4DV3ZXBIGF7L
#     Adding 72 records...
# New cache has 215766 records, saving.
# 675801 :done!
# Using cache
# Using 234544 records from cache
# Loading from http://thingspeak.com/channels/675805/feeds/entry/234545.json?api_key=T7I8LW37U46H7L9L
# Loading from http://thingspeak.com/channels/675805/feeds.json?start=2019-10-11T11:44:00Z&end=2019-10-11T11:45:21Z&api_key=T7I8LW37U46H7L9L
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675805/feeds/entry/242544.json?api_key=T7I8LW37U46H7L9L
# Loading from http://thingspeak.com/channels/675805/feeds.json?start=2019-10-11T11:45:22Z&end=2019-10-11T20:03:56Z&api_key=T7I8LW37U46H7L9L
#     Adding 246 records...
# New cache has 234790 records, saving.
# 675805 :done!
# Using cache
# Using 205831 records from cache
# Loading from http://thingspeak.com/channels/675851/feeds/entry/205832.json?api_key=UJDHKVXFA7MCWUIN
# Loading from http://thingspeak.com/channels/675851/feeds.json?start=2019-10-11T11:43:54Z&end=2019-10-11T11:45:21Z&api_key=UJDHKVXFA7MCWUIN
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675851/feeds/entry/213831.json?api_key=UJDHKVXFA7MCWUIN
# Loading from http://thingspeak.com/channels/675851/feeds.json?start=2019-10-11T11:45:22Z&end=2019-10-11T20:04:13Z&api_key=UJDHKVXFA7MCWUIN
#     Adding 98 records...
# New cache has 205929 records, saving.
# 675851 :done!
# Using cache
# Using 173717 records from cache
# Loading from http://thingspeak.com/channels/675991/feeds/entry/173718.json?api_key=WIK7QY0GKOYZFYB6
# Loading from http://thingspeak.com/channels/675991/feeds.json?start=2019-10-11T11:44:09Z&end=2019-10-11T11:46:33Z&api_key=WIK7QY0GKOYZFYB6
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675991/feeds/entry/181717.json?api_key=WIK7QY0GKOYZFYB6
# Loading from http://thingspeak.com/channels/675991/feeds.json?start=2019-10-11T11:46:34Z&end=2019-10-11T20:04:28Z&api_key=WIK7QY0GKOYZFYB6
#     Adding 212 records...
# New cache has 173929 records, saving.
# 675991 :done!
# Using cache
# Using 221338 records from cache
# Loading from http://thingspeak.com/channels/676000/feeds/entry/221339.json?api_key=R1UWA4NKVLEWRT8A
# Loading from http://thingspeak.com/channels/676000/feeds.json?start=2019-10-08T15:58:00Z&end=2019-10-11T20:04:43Z&api_key=R1UWA4NKVLEWRT8A
#     Adding 0 records...
# New cache has 221338 records, saving.
# 676000 :done!
# Using cache
# Using 5567 records from cache
# Loading from http://thingspeak.com/channels/689508/feeds/entry/5568.json?api_key=W3TREK1FFIFCQET6
# Loading from http://thingspeak.com/channels/689508/feeds.json?start=2019-06-14T08:21:30Z&end=2019-10-11T20:04:52Z&api_key=W3TREK1FFIFCQET6
#     Adding 0 records...
# New cache has 5567 records, saving.
# 689508 :done!
# Using cache
# Using 58445 records from cache
# Loading from http://thingspeak.com/channels/689511/feeds/entry/58446.json?api_key=GZMTUYFZ3WKL09DA
# Loading from http://thingspeak.com/channels/689511/feeds.json?start=2019-08-04T13:35:48Z&end=2019-10-11T20:04:57Z&api_key=GZMTUYFZ3WKL09DA
#     Adding 0 records...
# New cache has 58445 records, saving.
# 689511 :done!
# Using cache
# Using 183120 records from cache
# Loading from http://thingspeak.com/channels/689516/feeds/entry/183121.json?api_key=N6OC9S4QP5R26D38
# Loading from http://thingspeak.com/channels/689516/feeds.json?start=2019-10-11T11:45:17Z&end=2019-10-11T11:46:41Z&api_key=N6OC9S4QP5R26D38
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689516/feeds/entry/191120.json?api_key=N6OC9S4QP5R26D38
# Loading from http://thingspeak.com/channels/689516/feeds.json?start=2019-10-11T11:46:42Z&end=2019-10-11T20:05:06Z&api_key=N6OC9S4QP5R26D38
#     Adding 141 records...
# New cache has 183261 records, saving.
# 689516 :done!
# Using cache
# Using 117134 records from cache
# Loading from http://thingspeak.com/channels/689518/feeds/entry/117135.json?api_key=SP661YXSYJLE091E
# Loading from http://thingspeak.com/channels/689518/feeds.json?start=2019-10-11T11:45:48Z&end=2019-10-11T11:47:01Z&api_key=SP661YXSYJLE091E
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689518/feeds/entry/125134.json?api_key=SP661YXSYJLE091E
# Loading from http://thingspeak.com/channels/689518/feeds.json?start=2019-10-11T11:47:02Z&end=2019-10-11T20:05:18Z&api_key=SP661YXSYJLE091E
#     Adding 149 records...
# New cache has 117283 records, saving.
# 689518 :done!
# Using cache
# Using 98979 records from cache
# Loading from http://thingspeak.com/channels/689520/feeds/entry/98980.json?api_key=LUY3VEB20UIE4G1I
# Loading from http://thingspeak.com/channels/689520/feeds.json?start=2019-10-11T11:45:45Z&end=2019-10-11T11:47:04Z&api_key=LUY3VEB20UIE4G1I
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689520/feeds/entry/106979.json?api_key=LUY3VEB20UIE4G1I
# Loading from http://thingspeak.com/channels/689520/feeds.json?start=2019-10-11T11:47:05Z&end=2019-10-11T20:05:28Z&api_key=LUY3VEB20UIE4G1I
#     Adding 236 records...
# New cache has 99215 records, saving.
# 689520 :done!
# Using cache
# Using 165780 records from cache
# Loading from http://thingspeak.com/channels/689522/feeds/entry/165781.json?api_key=KRK2MEGVMD22YY59
# Loading from http://thingspeak.com/channels/689522/feeds.json?start=2019-10-11T11:46:13Z&end=2019-10-11T11:47:25Z&api_key=KRK2MEGVMD22YY59
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689522/feeds/entry/173780.json?api_key=KRK2MEGVMD22YY59
# Loading from http://thingspeak.com/channels/689522/feeds.json?start=2019-10-11T11:47:26Z&end=2019-10-11T20:05:40Z&api_key=KRK2MEGVMD22YY59
#     Adding 228 records...
# New cache has 166008 records, saving.
# 689522 :done!
# Using cache
# Using 116709 records from cache
# Loading from http://thingspeak.com/channels/689525/feeds/entry/116710.json?api_key=NWFG4DF3K0KEYT15
# Loading from http://thingspeak.com/channels/689525/feeds.json?start=2019-10-11T11:45:31Z&end=2019-10-11T11:47:00Z&api_key=NWFG4DF3K0KEYT15
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689525/feeds/entry/124709.json?api_key=NWFG4DF3K0KEYT15
# Loading from http://thingspeak.com/channels/689525/feeds.json?start=2019-10-11T11:47:01Z&end=2019-10-11T20:05:52Z&api_key=NWFG4DF3K0KEYT15
#     Adding 217 records...
# New cache has 116926 records, saving.
# 689525 :done!
# Using cache
# Using 110907 records from cache
# Loading from http://thingspeak.com/channels/689530/feeds/entry/110908.json?api_key=9FWEYOXMJHJG0PEB
# Loading from http://thingspeak.com/channels/689530/feeds.json?start=2019-10-11T11:45:45Z&end=2019-10-11T11:47:10Z&api_key=9FWEYOXMJHJG0PEB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689530/feeds/entry/118907.json?api_key=9FWEYOXMJHJG0PEB
# Loading from http://thingspeak.com/channels/689530/feeds.json?start=2019-10-11T11:47:11Z&end=2019-10-11T20:06:03Z&api_key=9FWEYOXMJHJG0PEB
#     Adding 187 records...
# New cache has 111094 records, saving.
# 689530 :done!
# Using cache
# Using 59433 records from cache
# Loading from http://thingspeak.com/channels/689532/feeds/entry/59434.json?api_key=2GGXH0YLJC992BLG
# Loading from http://thingspeak.com/channels/689532/feeds.json?start=2019-06-28T14:49:55Z&end=2019-10-11T20:06:11Z&api_key=2GGXH0YLJC992BLG
#     Adding 0 records...
# New cache has 59433 records, saving.
# 689532 :done!
# Using cache
# Using 147852 records from cache
# Loading from http://thingspeak.com/channels/689749/feeds/entry/147853.json?api_key=1CF1BEEI1OJ67E3H
# Loading from http://thingspeak.com/channels/689749/feeds.json?start=2019-10-11T11:46:33Z&end=2019-10-11T11:47:43Z&api_key=1CF1BEEI1OJ67E3H
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689749/feeds/entry/155852.json?api_key=1CF1BEEI1OJ67E3H
# Loading from http://thingspeak.com/channels/689749/feeds.json?start=2019-10-11T11:47:44Z&end=2019-10-11T20:06:21Z&api_key=1CF1BEEI1OJ67E3H
#     Adding 223 records...
# New cache has 148075 records, saving.
# 689749 :done!
# Using cache
# Using 182715 records from cache
# Loading from http://thingspeak.com/channels/689750/feeds/entry/182716.json?api_key=LWGIC3U8ZR004J04
# Loading from http://thingspeak.com/channels/689750/feeds.json?start=2019-10-11T11:47:23Z&end=2019-10-11T11:48:50Z&api_key=LWGIC3U8ZR004J04
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689750/feeds/entry/190715.json?api_key=LWGIC3U8ZR004J04
# Loading from http://thingspeak.com/channels/689750/feeds.json?start=2019-10-11T11:48:51Z&end=2019-10-11T20:06:33Z&api_key=LWGIC3U8ZR004J04
#     Adding 236 records...
# New cache has 182951 records, saving.
# 689750 :done!
# Using cache
# Using 59771 records from cache
# Loading from http://thingspeak.com/channels/689752/feeds/entry/59772.json?api_key=98KV1E257QS3SASB
# Loading from http://thingspeak.com/channels/689752/feeds.json?start=2019-10-11T07:16:12Z&end=2019-10-11T14:37:58Z&api_key=98KV1E257QS3SASB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689752/feeds/entry/67771.json?api_key=98KV1E257QS3SASB
# Loading from http://thingspeak.com/channels/689752/feeds.json?start=2019-10-11T14:37:59Z&end=2019-10-11T20:06:48Z&api_key=98KV1E257QS3SASB
#     Adding 107 records...
# New cache has 59878 records, saving.
# 689752 :done!
# Using cache
# Using 106302 records from cache
# Loading from http://thingspeak.com/channels/689753/feeds/entry/106303.json?api_key=1FL0QL9OTDMN9T33
# Loading from http://thingspeak.com/channels/689753/feeds.json?start=2019-10-11T11:47:14Z&end=2019-10-11T11:48:27Z&api_key=1FL0QL9OTDMN9T33
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689753/feeds/entry/114302.json?api_key=1FL0QL9OTDMN9T33
# Loading from http://thingspeak.com/channels/689753/feeds.json?start=2019-10-11T11:48:28Z&end=2019-10-11T20:06:58Z&api_key=1FL0QL9OTDMN9T33
#     Adding 244 records...
# New cache has 106546 records, saving.
# 689753 :done!
# Using cache
# Using 167022 records from cache
# Loading from http://thingspeak.com/channels/689756/feeds/entry/167023.json?api_key=EIVEW4EZHD38VLN7
# Loading from http://thingspeak.com/channels/689756/feeds.json?start=2019-10-11T11:47:05Z&end=2019-10-11T11:48:31Z&api_key=EIVEW4EZHD38VLN7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689756/feeds/entry/175022.json?api_key=EIVEW4EZHD38VLN7
# Loading from http://thingspeak.com/channels/689756/feeds.json?start=2019-10-11T11:48:32Z&end=2019-10-11T20:07:09Z&api_key=EIVEW4EZHD38VLN7
#     Adding 116 records...
# New cache has 167138 records, saving.
# 689756 :done!
# Using cache
# Using 152201 records from cache
# Loading from http://thingspeak.com/channels/689759/feeds/entry/152202.json?api_key=FG9PD1OUD9OLGZB3
# Loading from http://thingspeak.com/channels/689759/feeds.json?start=2019-10-11T11:47:21Z&end=2019-10-11T11:48:49Z&api_key=FG9PD1OUD9OLGZB3
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689759/feeds/entry/160201.json?api_key=FG9PD1OUD9OLGZB3
# Loading from http://thingspeak.com/channels/689759/feeds.json?start=2019-10-11T11:48:50Z&end=2019-10-11T20:07:21Z&api_key=FG9PD1OUD9OLGZB3
#     Adding 95 records...
# New cache has 152296 records, saving.
# 689759 :done!
# Using cache
# Using 209118 records from cache
# Loading from http://thingspeak.com/channels/689761/feeds/entry/209119.json?api_key=YEGZIVUS16X2R4BO
# Loading from http://thingspeak.com/channels/689761/feeds.json?start=2019-10-11T11:48:19Z&end=2019-10-11T11:49:32Z&api_key=YEGZIVUS16X2R4BO
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689761/feeds/entry/217118.json?api_key=YEGZIVUS16X2R4BO
# Loading from http://thingspeak.com/channels/689761/feeds.json?start=2019-10-11T11:49:33Z&end=2019-10-11T20:07:32Z&api_key=YEGZIVUS16X2R4BO
#     Adding 244 records...
# New cache has 209362 records, saving.
# 689761 :done!
# Using cache
# Using 64519 records from cache
# Loading from http://thingspeak.com/channels/689766/feeds/entry/64520.json?api_key=3XTH7YLBLURX0XQB
# Loading from http://thingspeak.com/channels/689766/feeds.json?start=2019-10-11T11:49:26Z&end=2019-10-11T11:50:53Z&api_key=3XTH7YLBLURX0XQB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689766/feeds/entry/72519.json?api_key=3XTH7YLBLURX0XQB
# Loading from http://thingspeak.com/channels/689766/feeds.json?start=2019-10-11T11:50:54Z&end=2019-10-11T20:07:45Z&api_key=3XTH7YLBLURX0XQB
#     Adding 160 records...
# New cache has 64679 records, saving.
# 689766 :done!
# Using cache
# Using 16981 records from cache
# Loading from http://thingspeak.com/channels/689768/feeds/entry/16982.json?api_key=IKZL0YTFYDWN701G
# Loading from http://thingspeak.com/channels/689768/feeds.json?start=2019-04-27T20:35:31Z&end=2019-10-11T20:07:51Z&api_key=IKZL0YTFYDWN701G
#     Adding 0 records...
# New cache has 16981 records, saving.
# 689768 :done!
# Using cache
# Using 208624 records from cache
# Loading from http://thingspeak.com/channels/718028/feeds/entry/208625.json?api_key=HNTV5QEJTD8RTG2H
# Loading from http://thingspeak.com/channels/718028/feeds.json?start=2019-10-11T11:48:31Z&end=2019-10-11T11:49:53Z&api_key=HNTV5QEJTD8RTG2H
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718028/feeds/entry/216624.json?api_key=HNTV5QEJTD8RTG2H
# Loading from http://thingspeak.com/channels/718028/feeds.json?start=2019-10-11T11:49:54Z&end=2019-10-11T20:07:59Z&api_key=HNTV5QEJTD8RTG2H
#     Adding 244 records...
# New cache has 208868 records, saving.
# 718028 :done!
# Using cache
# Using 186312 records from cache
# Loading from http://thingspeak.com/channels/718029/feeds/entry/186313.json?api_key=TRF8VHH9DWUKBT59
# Loading from http://thingspeak.com/channels/718029/feeds.json?start=2019-10-11T11:49:56Z&end=2019-10-11T11:52:40Z&api_key=TRF8VHH9DWUKBT59
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718029/feeds/entry/194312.json?api_key=TRF8VHH9DWUKBT59
# Loading from http://thingspeak.com/channels/718029/feeds.json?start=2019-10-11T11:52:41Z&end=2019-10-11T20:08:13Z&api_key=TRF8VHH9DWUKBT59
#     Adding 229 records...
# New cache has 186541 records, saving.
# 718029 :done!
# Using cache
# Using 199366 records from cache
# Loading from http://thingspeak.com/channels/718030/feeds/entry/199367.json?api_key=2VDX6R4QQY92HH7A
# Loading from http://thingspeak.com/channels/718030/feeds.json?start=2019-10-11T11:50:28Z&end=2019-10-11T11:51:51Z&api_key=2VDX6R4QQY92HH7A
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718030/feeds/entry/207366.json?api_key=2VDX6R4QQY92HH7A
# Loading from http://thingspeak.com/channels/718030/feeds.json?start=2019-10-11T11:51:52Z&end=2019-10-11T20:08:26Z&api_key=2VDX6R4QQY92HH7A
#     Adding 245 records...
# New cache has 199611 records, saving.
# 718030 :done!
# Using cache
# Using 185053 records from cache
# Loading from http://thingspeak.com/channels/730014/feeds/entry/185054.json?api_key=8A9OOESUKHXIE80Z
# Loading from http://thingspeak.com/channels/730014/feeds.json?start=2019-10-11T11:50:42Z&end=2019-10-11T11:51:57Z&api_key=8A9OOESUKHXIE80Z
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730014/feeds/entry/193053.json?api_key=8A9OOESUKHXIE80Z
# Loading from http://thingspeak.com/channels/730014/feeds.json?start=2019-10-11T11:51:58Z&end=2019-10-11T20:08:40Z&api_key=8A9OOESUKHXIE80Z
#     Adding 243 records...
# New cache has 185296 records, saving.
# 730014 :done!
# Using cache
# Using 193083 records from cache
# Loading from http://thingspeak.com/channels/730015/feeds/entry/193084.json?api_key=IWDN2EZTU4IA2ZPW
# Loading from http://thingspeak.com/channels/730015/feeds.json?start=2019-10-11T11:50:23Z&end=2019-10-11T11:51:45Z&api_key=IWDN2EZTU4IA2ZPW
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730015/feeds/entry/201083.json?api_key=IWDN2EZTU4IA2ZPW
# Loading from http://thingspeak.com/channels/730015/feeds.json?start=2019-10-11T11:51:46Z&end=2019-10-11T20:08:53Z&api_key=IWDN2EZTU4IA2ZPW
#     Adding 243 records...
# New cache has 193326 records, saving.
# 730015 :done!
# Using cache
# Using 171418 records from cache
# Loading from http://thingspeak.com/channels/730016/feeds/entry/171419.json?api_key=C5HH5TN5WK8TPQOQ
# Loading from http://thingspeak.com/channels/730016/feeds.json?start=2019-10-11T11:51:02Z&end=2019-10-11T11:52:30Z&api_key=C5HH5TN5WK8TPQOQ
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730016/feeds/entry/179418.json?api_key=C5HH5TN5WK8TPQOQ
# Loading from http://thingspeak.com/channels/730016/feeds.json?start=2019-10-11T11:52:31Z&end=2019-10-11T20:09:05Z&api_key=C5HH5TN5WK8TPQOQ
#     Adding 120 records...
# New cache has 171538 records, saving.
# 730016 :done!
# Using cache
# Using 167697 records from cache
# Loading from http://thingspeak.com/channels/730019/feeds/entry/167698.json?api_key=Y1VA42KWZFE7MJDZ
# Loading from http://thingspeak.com/channels/730019/feeds.json?start=2019-10-09T18:02:59Z&end=2019-10-11T20:09:14Z&api_key=Y1VA42KWZFE7MJDZ
#     Adding 0 records...
# New cache has 167697 records, saving.
# 730019 :done!
# Using cache
# Using 148066 records from cache
# Loading from http://thingspeak.com/channels/737273/feeds/entry/148067.json?api_key=5QFKQIGSKJK517SZ
# Loading from http://thingspeak.com/channels/737273/feeds.json?start=2019-10-07T18:14:29Z&end=2019-10-11T20:09:22Z&api_key=5QFKQIGSKJK517SZ
#     Adding 0 records...
# New cache has 148066 records, saving.
# 737273 :done!
# Using cache
# Using 35037 records from cache
# Loading from http://thingspeak.com/channels/737274/feeds/entry/35038.json?api_key=UX5TORPRJKXR3YZ1
# Loading from http://thingspeak.com/channels/737274/feeds.json?start=2019-06-11T05:48:12Z&end=2019-10-11T20:09:29Z&api_key=UX5TORPRJKXR3YZ1
#     Adding 0 records...
# New cache has 35037 records, saving.
# 737274 :done!
# Using cache
# Using 22183 records from cache
# Loading from http://thingspeak.com/channels/737275/feeds/entry/22184.json?api_key=0TVL12ZFTQXQJACL
# Loading from http://thingspeak.com/channels/737275/feeds.json?start=2019-07-04T17:18:52Z&end=2019-10-11T20:09:33Z&api_key=0TVL12ZFTQXQJACL
#     Adding 0 records...
# New cache has 22183 records, saving.
# 737275 :done!
# Using cache
# Using 190452 records from cache
# Loading from http://thingspeak.com/channels/737276/feeds/entry/190453.json?api_key=VHE2PZCJLMYHB7ZI
# Loading from http://thingspeak.com/channels/737276/feeds.json?start=2019-10-11T11:51:00Z&end=2019-10-11T11:52:21Z&api_key=VHE2PZCJLMYHB7ZI
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/737276/feeds/entry/198452.json?api_key=VHE2PZCJLMYHB7ZI
# Loading from http://thingspeak.com/channels/737276/feeds.json?start=2019-10-11T11:52:22Z&end=2019-10-11T20:09:41Z&api_key=VHE2PZCJLMYHB7ZI
#     Adding 242 records...
# New cache has 190694 records, saving.
# 737276 :done!
# Using cache
# Using 155590 records from cache
# Loading from http://thingspeak.com/channels/737278/feeds/entry/155591.json?api_key=U0PR0AUGQU2K5JQC
# Loading from http://thingspeak.com/channels/737278/feeds.json?start=2019-10-11T11:51:47Z&end=2019-10-11T11:52:43Z&api_key=U0PR0AUGQU2K5JQC
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/737278/feeds/entry/163590.json?api_key=U0PR0AUGQU2K5JQC
# Loading from http://thingspeak.com/channels/737278/feeds.json?start=2019-10-11T11:52:44Z&end=2019-10-11T20:09:54Z&api_key=U0PR0AUGQU2K5JQC
#     Adding 242 records...
# New cache has 155832 records, saving.
# 737278 :done!
# Using cache
# Using 153428 records from cache
# Loading from http://thingspeak.com/channels/755609/feeds/entry/153429.json?api_key=BI5JRX3TJ8LTWLU0
# Loading from http://thingspeak.com/channels/755609/feeds.json?start=2019-10-10T08:06:53Z&end=2019-10-11T20:10:03Z&api_key=BI5JRX3TJ8LTWLU0
#     Adding 0 records...
# New cache has 153428 records, saving.
# 755609 :done!
# Using cache
# Using 7571 records from cache
# Loading from http://thingspeak.com/channels/755610/feeds/entry/7572.json?api_key=YPB4XZHBPI1MA358
# Loading from http://thingspeak.com/channels/755610/feeds.json?start=2019-05-21T12:01:55Z&end=2019-10-11T20:10:10Z&api_key=YPB4XZHBPI1MA358
#     Adding 0 records...
# New cache has 7571 records, saving.
# 755610 :done!
# Using cache
# Using 131875 records from cache
# Loading from http://thingspeak.com/channels/755612/feeds/entry/131876.json?api_key=AZ3Q42XK8FOUF8P7
# Loading from http://thingspeak.com/channels/755612/feeds.json?start=2019-10-11T11:52:32Z&end=2019-10-11T11:53:50Z&api_key=AZ3Q42XK8FOUF8P7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/755612/feeds/entry/139875.json?api_key=AZ3Q42XK8FOUF8P7
# Loading from http://thingspeak.com/channels/755612/feeds.json?start=2019-10-11T11:53:51Z&end=2019-10-11T20:10:17Z&api_key=AZ3Q42XK8FOUF8P7
#     Adding 170 records...
# New cache has 132045 records, saving.
# 755612 :done!
# Using cache
# Using 141225 records from cache
# Loading from http://thingspeak.com/channels/755614/feeds/entry/141226.json?api_key=NZE1II9NGDOMN3BS
# Loading from http://thingspeak.com/channels/755614/feeds.json?start=2019-10-11T11:52:51Z&end=2019-10-11T11:54:04Z&api_key=NZE1II9NGDOMN3BS
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/755614/feeds/entry/149225.json?api_key=NZE1II9NGDOMN3BS
# Loading from http://thingspeak.com/channels/755614/feeds.json?start=2019-10-11T11:54:05Z&end=2019-10-11T20:10:29Z&api_key=NZE1II9NGDOMN3BS
#     Adding 245 records...
# New cache has 141470 records, saving.
# 755614 :done!
# Using cache
# Using 84944 records from cache
# Loading from http://thingspeak.com/channels/782718/feeds/entry/84945.json?api_key=Q5UUO172BQ33X8S1
# Loading from http://thingspeak.com/channels/782718/feeds.json?start=2019-10-11T11:51:24Z&end=2019-10-11T12:04:32Z&api_key=Q5UUO172BQ33X8S1
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782718/feeds/entry/92944.json?api_key=Q5UUO172BQ33X8S1
# Loading from http://thingspeak.com/channels/782718/feeds.json?start=2019-10-11T12:04:33Z&end=2019-10-11T20:10:41Z&api_key=Q5UUO172BQ33X8S1
#     Adding 135 records...
# New cache has 85079 records, saving.
# 782718 :done!
# Using cache
# Using 120504 records from cache
# Loading from http://thingspeak.com/channels/782719/feeds/entry/120505.json?api_key=QTNAHITKHEJ4C9I5
# Loading from http://thingspeak.com/channels/782719/feeds.json?start=2019-10-11T11:53:34Z&end=2019-10-11T11:54:53Z&api_key=QTNAHITKHEJ4C9I5
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782719/feeds/entry/128504.json?api_key=QTNAHITKHEJ4C9I5
# Loading from http://thingspeak.com/channels/782719/feeds.json?start=2019-10-11T11:54:54Z&end=2019-10-11T20:10:51Z&api_key=QTNAHITKHEJ4C9I5
#     Adding 229 records...
# New cache has 120733 records, saving.
# 782719 :done!
# Using cache
# Using 97013 records from cache
# Loading from http://thingspeak.com/channels/782720/feeds/entry/97014.json?api_key=7ZN35W0OYQQ1A2ZC
# Loading from http://thingspeak.com/channels/782720/feeds.json?start=2019-10-11T11:55:24Z&end=2019-10-11T11:56:36Z&api_key=7ZN35W0OYQQ1A2ZC
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782720/feeds/entry/105013.json?api_key=7ZN35W0OYQQ1A2ZC
# Loading from http://thingspeak.com/channels/782720/feeds.json?start=2019-10-11T11:56:37Z&end=2019-10-11T20:11:02Z&api_key=7ZN35W0OYQQ1A2ZC
#     Adding 150 records...
# New cache has 97163 records, saving.
# 782720 :done!
# Using cache
# Using 105816 records from cache
# Loading from http://thingspeak.com/channels/782721/feeds/entry/105817.json?api_key=QU3CSDCF0X5X1S06
# Loading from http://thingspeak.com/channels/782721/feeds.json?start=2019-10-11T11:54:17Z&end=2019-10-11T11:55:38Z&api_key=QU3CSDCF0X5X1S06
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782721/feeds/entry/113816.json?api_key=QU3CSDCF0X5X1S06
# Loading from http://thingspeak.com/channels/782721/feeds.json?start=2019-10-11T11:55:39Z&end=2019-10-11T20:11:13Z&api_key=QU3CSDCF0X5X1S06
#     Adding 195 records...
# New cache has 106011 records, saving.
# 782721 :done!
# Using cache
# Using 92001 records from cache
# Loading from http://thingspeak.com/channels/782722/feeds/entry/92002.json?api_key=OGG3UX99KTA41C1K
# Loading from http://thingspeak.com/channels/782722/feeds.json?start=2019-10-11T11:55:16Z&end=2019-10-11T11:59:41Z&api_key=OGG3UX99KTA41C1K
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782722/feeds/entry/100001.json?api_key=OGG3UX99KTA41C1K
# Loading from http://thingspeak.com/channels/782722/feeds.json?start=2019-10-11T11:59:42Z&end=2019-10-11T20:11:23Z&api_key=OGG3UX99KTA41C1K
#     Adding 60 records...
# New cache has 92061 records, saving.
# 782722 :done!
# Using cache
# Using 58 records from cache
# Loading from http://thingspeak.com/channels/782723/feeds/entry/59.json?api_key=DNB8Q1WI3PO7000T
# Loading from http://thingspeak.com/channels/782723/feeds.json?start=2019-07-24T11:19:35Z&end=2019-10-11T20:11:29Z&api_key=DNB8Q1WI3PO7000T
#     Adding 0 records...
# New cache has 58 records, saving.
# 782723 :done!
# Using cache
# Using 68098 records from cache
# Loading from http://thingspeak.com/channels/832251/feeds/entry/68099.json?api_key=LRAC4HSQ3H0JSUW4
# Loading from http://thingspeak.com/channels/832251/feeds.json?start=2019-10-11T11:56:17Z&end=2019-10-11T11:57:43Z&api_key=LRAC4HSQ3H0JSUW4
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/832251/feeds/entry/76098.json?api_key=LRAC4HSQ3H0JSUW4
# Loading from http://thingspeak.com/channels/832251/feeds.json?start=2019-10-11T11:57:44Z&end=2019-10-11T20:11:39Z&api_key=LRAC4HSQ3H0JSUW4
#     Adding 217 records...
# New cache has 68315 records, saving.
# 832251 :done!
# Using cache
# Using 111013 records from cache
# Loading from http://thingspeak.com/channels/742703/feeds/entry/111014.json?api_key=MSHOGX6N0EYY140G
# Loading from http://thingspeak.com/channels/742703/feeds.json?start=2019-05-26T08:13:37Z&end=2019-10-11T20:11:45Z&api_key=MSHOGX6N0EYY140G
#     Adding 0 records...
# New cache has 111013 records, saving.
# 742703 :done!
# Using cache
# Using 153905 records from cache
# Loading from http://thingspeak.com/channels/741339/feeds/entry/153906.json?api_key=LY78C6EEGO3RT04V
# Loading from http://thingspeak.com/channels/741339/feeds.json?start=2019-09-25T11:45:04Z&end=2019-10-11T20:11:56Z&api_key=LY78C6EEGO3RT04V
#     Adding 0 records...
# New cache has 153905 records, saving.
# 741339 :done!
# Using cache
# Using 43068 records from cache
# Loading from http://thingspeak.com/channels/741341/feeds/entry/43069.json?api_key=HUDSTF69DDZM7IPP
# Loading from http://thingspeak.com/channels/741341/feeds.json?start=2019-03-05T20:53:04Z&end=2019-10-11T20:12:04Z&api_key=HUDSTF69DDZM7IPP
#     Adding 0 records...
# New cache has 43068 records, saving.
# 741341 :done!
# Using cache
# Using 15993 records from cache
# Loading from http://thingspeak.com/channels/741342/feeds/entry/15994.json?api_key=5MSX75QS74WTEOSD
# Loading from http://thingspeak.com/channels/741342/feeds.json?start=2019-09-19T10:24:14Z&end=2019-10-11T20:12:11Z&api_key=5MSX75QS74WTEOSD
#     Adding 0 records...
# New cache has 15993 records, saving.
# 741342 :done!

# %%
#Column names for the different types of sensors
PMS_heads_7 = ['time', 'entry_id', 'pm2_5', 'pm10', 's2_pm2_5', 's2_pm10', 'lat', 'long', 'voltage', 'channel_id']
PMS_heads_8 = ['time', 'entry_id', 'pm2_5', 'pm10', 's2_pm2_5', 's2_pm10', 'lat', 'long', 'voltage', 'gps_data', 'channel_id']
OPC_N2_heads_7 = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'sample_period', 'lat', 'long', 'voltage', 'channel_id']
OPC_N2_heads_8 = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'sample_period', 'lat', 'long', 'voltage', 'gps_data', 'channel_id']
PA_heads = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'uptime', 'RSSI', 'temp', 'humidity', 'pm2_5_cf1', 'channel_id']

# %%
# creating a dictionary of the csv file names and their respective csv files
channel_name_dict = dict(zip(metadata_df['channel_name'], channel_data_list)) #where keys=filenames and values=dataframes

# %%
# Setting the column names for the different csv files based on the file name
for filename, dataframe in channel_name_dict.items():
                    
    rows,columns = dataframe.shape
    
    if (('AQ_' in filename) and (columns==11)):
        channel_name_dict[filename].columns = PMS_heads_8
        #print (filename, ': PMS_heads_8')
            
    elif(('AQ_' in filename) and (columns==10)):
        channel_name_dict[filename].columns = PMS_heads_7  
        #print (filename, ': PMS_heads_7')
            
    elif ('PA' in filename):
        channel_name_dict[filename].columns = PA_heads
        #print (filename, ': PA')            
            
    elif (('8A' in filename) or ('6F' in filename)):
        channel_name_dict[filename].columns = OPC_N2_heads_8   
        #print (filename, ': 8A/6F')
            
    else:
        channel_name_dict[filename].columns = OPC_N2_heads_7
        #print (filename, ': the rest')

# %%
#Adding latitude and longitude coordinates for Purple Air Sensors
for filename, dataframe in channel_name_dict.items():
    if ('PA_01' in filename): #International School Lubowa
        dataframe['lat'] = 0.2357
        dataframe['long'] = 32.5576
        #print (dataframe.head())
    elif ('PA_02' in filename): #Makerere
        dataframe['lat'] = 0.332050  #estimates
        dataframe['long'] = 32.570509
    elif ('PA_03' in filename): #Kabale
        dataframe['lat'] = -1.245 
        dataframe['long'] = 29.9892
    elif ('PA_04' in filename): #Bunamwaya
        dataframe['lat'] = 0.27
        dataframe['long'] = 32.558

# %%
def connect_mongo(db, host='localhost', port=27017, ):
    """ A util for making a connection to mongo """

    conn = MongoClient(host, port)
    return conn[db]

# %%
db =connect_mongo('channel_db')

# %%
count = 1

# %%
for filename,dataframe in channel_name_dict.items():
    
    dataframe['lat'] = dataframe['lat'].replace([0.000000,1000.000000], np.nan)
    dataframe['long'] = dataframe['long'].replace([0.000000,1000.000000], np.nan)
    
    records = json.loads(dataframe.T.to_json()).values()
    db.channeldata_collection.insert_many(records)
    print('Channel %d successful!' %count)
    
    count+=1
# Out:
# Channel 1 successful!
# Channel 2 successful!
# Channel 3 successful!
# Channel 4 successful!
# Channel 5 successful!
# Channel 6 successful!
# Channel 7 successful!
# Channel 8 successful!
# Channel 9 successful!
# Channel 10 successful!
# Channel 11 successful!
# Channel 12 successful!
# Channel 13 successful!
# Channel 14 successful!
# Channel 15 successful!
# Channel 16 successful!
# Channel 17 successful!
# Channel 18 successful!
# Channel 19 successful!
# Channel 20 successful!
# Channel 21 successful!
# Channel 22 successful!
# Channel 23 successful!
# Channel 24 successful!
# Channel 25 successful!
# Channel 26 successful!
# Channel 27 successful!
# Channel 28 successful!
# Channel 29 successful!
# Channel 30 successful!
# Channel 31 successful!
# Channel 32 successful!
# Channel 33 successful!
# Channel 34 successful!
# Channel 35 successful!
# Channel 36 successful!
# Channel 37 successful!
# Channel 38 successful!
# Channel 39 successful!
# Channel 40 successful!
# Channel 41 successful!
# Channel 42 successful!
# Channel 43 successful!
# Channel 44 successful!
# Channel 45 successful!
# Channel 46 successful!
# Channel 47 successful!
# Channel 48 successful!
# Channel 49 successful!
# Channel 50 successful!
# Channel 51 successful!
# Channel 52 successful!
# Channel 53 successful!
# Channel 54 successful!
# Channel 55 successful!
