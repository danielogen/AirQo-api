# %%
import pandas as pd
import numpy as np

import glob
import os

import datetime as dt
from datetime import datetime,timedelta
from pytz import all_timezones

import json, requests
import pickle
import OpenSSL

from pymongo import MongoClient

# %%
#function that downloads all channel data form ThingSpeak
def download(apiurl,cache='use',verbose=False,apikey=None,cacheonly=None):
    """
    download(apiurl,cache='use',verbose=False,apikey=None):
    Loads thingspeak data from apiurl
    Set cache to:
        'use' - to use it
        'refresh' - to not use it
        'only' - to only use it
    cacheonly = if set, only cache this many previous training points,
       will only report this many when output. This is useful to avoid
       caches becoming arbitrarily large with historic data.
    """
    filename = 'channel%s.p'%apiurl.split('/')[-1]
    cachefile = os.path.isfile(filename)
    if (cache=='use' or cache=='only') and cachefile:
        alldata = pickle.load( open( filename, "rb" ) )
        if (cache=='only'):
            if verbose: print("Using just cache - may be out of date")
            return alldata
        if verbose: print("Using cache")
        nextid = alldata[-1]['entry_id']+1
        endtime = str_to_date(alldata[-1]['created_at'])+timedelta(seconds=1)
    else: #no cachefile or refresh -> we want to reload from the API
        if verbose: print("Ignoring/overwriting cache")
        if (cache=='only'):
            ##TODO Throw exception - can't only use cache as there is no cache
            assert False, "Can't only use cache as there is no cache"
        nextid = 1
        alldata = []
        endtime = None  
    if (cache=='only'): #we should stop now, and use the cached data we've got
        return alldata
        
    result = None
    if verbose: print("Using %d records from cache" % len(alldata))
    while result != -1:
        #thingspeak doesn't let you download ranges of ids, instead you have to
        #download ranges of dates. We can only download 8000 at a time, so we
        #need to get the date of the next one we need (then we ask for that datetime
        #until now, and repeat until we run out of new items).
        url = apiurl+'/feeds/entry/%d.json' % (nextid)
        if apikey is not None: url += '?api_key=%s' % apikey
        print("Loading from %s" % url)
        result = json.loads(requests.post(url, timeout = 100.0).content.decode('utf-8'))
        starttime = endtime
        if result==-1:
            #if verbose: print("Warning: Unable to retrieve data (does channel exist? is it public?)")
            endtime = datetime.now()
        else:
            endtime = str_to_date(result['created_at'])
        if (nextid==1):
            starttime = endtime
        else:
            start = datetime.strftime(starttime,'%Y-%m-%dT%H:%M:%SZ')
            end = datetime.strftime(endtime-timedelta(seconds=1),'%Y-%m-%dT%H:%M:%SZ')
            url = apiurl+'/feeds.json?start=%s&end=%s' % (start,end)
            if apikey is not None: url += '&api_key=%s' % apikey
            print("Loading from %s" % url)                        
            data = json.loads(requests.post(url, timeout = 100.0).content.decode('utf-8'))
            if (data!=-1):
                alldata.extend(data['feeds'])
                if verbose: print("    Adding %d records..." % len(data['feeds']))
            else:
                if verbose: print("Warning: unable to read data feed")
            
        nextid += 7999 #thought download was 8000 fields, but it's 8000 records. 8000/len(result)
    if verbose: print("New cache has %d records, saving." % len(alldata))
    
    if cacheonly is not None:
        pickle.dump( alldata[-cacheonly:], open( filename, "wb" ) )
    else:
        pickle.dump( alldata, open( filename, "wb" ) )
    return alldata

# %%
#Function that converts a string to datetime format
def str_to_date(st):
    return datetime.strptime(st,'%Y-%m-%dT%H:%M:%SZ')

# %%
#Function that imports csv files into a Mongo database
def mongoimportcsv(csv_path, db_name, collection_name, db_url='localhost', db_port=27000):
    client = MongoClient(db_url, db_port)
    db=client[db_name]
    collection=client(collection_name)
    
    data=pd.read_csv(csv_path)
    payload=json.loads(data.to_json(orient='records'))
    
    collection.remove()
    collection.insert(payload)
    return collection.count()

# %%
#These should go in a database
metadata_path = r'D:\LILLIAN\AirQo\channel_metadata.csv'
channel_metadata = pd.read_csv(metadata_path, encoding = "ISO-8859-1", dtype = {"channel_id" : "object"})
channel_metadata.head()
# Out:
#                         channel channel_name channel_id      read_api_key
# 0  AIRQO WB1 MOBILE UNIT ACTIVE        AQ_01     643676  MXMFGRF4ERL4VKI2
# 1  AIRQO-WB2 MOBILE UNIT ACTIVE        AQ_02     667402  A7E6OGD6QRIAVVK7
# 2  AIRQO-WB3 MOBILE UNIT ACTIVE        AQ_03     667406  1K40QAHJQLR3R6HB
# 3         AIRQO-WB4 UNIT ACTIVE        AQ_04     672528  YOW5ITSXCLW7IA0C
# 4         AIRQO-WB5 UNIT ACTIVE        AQ_05     675740  H3EY1WFQK4M2C2ZP

# %%
channel_ids = channel_metadata['channel_id']
channel_ids[:3]
# Out:
# 0    643676
# 1    667402
# 2    667406
# Name: channel_id, dtype: object

# %%
channel_keys= channel_metadata['read_api_key']
channel_keys[:3]
# Out:
# 0    MXMFGRF4ERL4VKI2
# 1    A7E6OGD6QRIAVVK7
# 2    1K40QAHJQLR3R6HB
# Name: read_api_key, dtype: object

# %%
channel_dict = dict(zip(channel_ids, channel_keys))
channel_dict.items()
# Out:
# dict_items([('643676', 'MXMFGRF4ERL4VKI2'), ('667402', 'A7E6OGD6QRIAVVK7'), ('667406', '1K40QAHJQLR3R6HB'), ('672528', 'YOW5ITSXCLW7IA0C'), ('675740', 'H3EY1WFQK4M2C2ZP'), ('675801', '0T0B4DV3ZXBIGF7L'), ('675805', 'T7I8LW37U46H7L9L'), ('675851', 'UJDHKVXFA7MCWUIN'), ('675991', 'WIK7QY0GKOYZFYB6'), ('676000', 'R1UWA4NKVLEWRT8A'), ('689508', 'W3TREK1FFIFCQET6'), ('689511', 'GZMTUYFZ3WKL09DA'), ('689516', 'N6OC9S4QP5R26D38'), ('689518', 'SP661YXSYJLE091E'), ('689520', 'LUY3VEB20UIE4G1I'), ('689522', 'KRK2MEGVMD22YY59'), ('689525', 'NWFG4DF3K0KEYT15'), ('689530', '9FWEYOXMJHJG0PEB'), ('689532', '2GGXH0YLJC992BLG'), ('689749', '1CF1BEEI1OJ67E3H'), ('689750', 'LWGIC3U8ZR004J04'), ('689752', '98KV1E257QS3SASB'), ('689753', '1FL0QL9OTDMN9T33'), ('689756', 'EIVEW4EZHD38VLN7'), ('689759', 'FG9PD1OUD9OLGZB3'), ('689761', 'YEGZIVUS16X2R4BO'), ('689766', '3XTH7YLBLURX0XQB'), ('689768', 'IKZL0YTFYDWN701G'), ('718028', 'HNTV5QEJTD8RTG2H'), ('718029', 'TRF8VHH9DWUKBT59'), ('718030', '2VDX6R4QQY92HH7A'), ('730014', '8A9OOESUKHXIE80Z'), ('730015', 'IWDN2EZTU4IA2ZPW'), ('730016', 'C5HH5TN5WK8TPQOQ'), ('730019', 'Y1VA42KWZFE7MJDZ'), ('737273', '5QFKQIGSKJK517SZ'), ('737274', 'UX5TORPRJKXR3YZ1'), ('737275', '0TVL12ZFTQXQJACL'), ('737276', 'VHE2PZCJLMYHB7ZI'), ('737278', 'U0PR0AUGQU2K5JQC'), ('755609', 'BI5JRX3TJ8LTWLU0'), ('755610', 'YPB4XZHBPI1MA358'), ('755612', 'AZ3Q42XK8FOUF8P7'), ('755614', 'NZE1II9NGDOMN3BS'), ('782718', 'Q5UUO172BQ33X8S1'), ('782719', 'QTNAHITKHEJ4C9I5'), ('782720', '7ZN35W0OYQQ1A2ZC'), ('782721', 'QU3CSDCF0X5X1S06'), ('782722', 'OGG3UX99KTA41C1K'), ('782723', 'DNB8Q1WI3PO7000T'), ('832251', 'LRAC4HSQ3H0JSUW4'), ('742703', 'MSHOGX6N0EYY140G'), ('741339', 'LY78C6EEGO3RT04V'), ('741341', 'HUDSTF69DDZM7IPP'), ('741342', '5MSX75QS74WTEOSD')])

# %%
channel_data_list = []
for channel_id, channel_key in channel_dict.items():
    channel_url = 'http://thingspeak.com/channels/'+str(channel_id)
    data = download(channel_url, verbose = True, apikey = channel_key)
    
    df = pd.DataFrame(data)#creating a dataframe of the data
    
    df['created_at'] =  pd.to_datetime(df['created_at']) #converting to DateTime format
    df['created_at'] = df['created_at'].dt.tz_convert('Africa/Kampala') #Converting from UTC to GMT
    
    df['channel_id'] = channel_id #adding an additional column
    channel_data_list.append(df)
    print(channel_id, ":done!")
# Out:
# Using cache
# Using 76984 records from cache
# Loading from http://thingspeak.com/channels/643676/feeds/entry/76985.json?api_key=MXMFGRF4ERL4VKI2
# Loading from http://thingspeak.com/channels/643676/feeds.json?start=2019-06-23T20:43:37Z&end=2019-10-10T10:22:34Z&api_key=MXMFGRF4ERL4VKI2
#     Adding 0 records...
# New cache has 76984 records, saving.
# 643676 :done!
# Using cache
# Using 164366 records from cache
# Loading from http://thingspeak.com/channels/667402/feeds/entry/164367.json?api_key=A7E6OGD6QRIAVVK7
# Loading from http://thingspeak.com/channels/667402/feeds.json?start=2019-10-10T06:55:35Z&end=2019-10-10T06:56:06Z&api_key=A7E6OGD6QRIAVVK7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/667402/feeds/entry/172366.json?api_key=A7E6OGD6QRIAVVK7
# Loading from http://thingspeak.com/channels/667402/feeds.json?start=2019-10-10T06:56:07Z&end=2019-10-10T10:22:50Z&api_key=A7E6OGD6QRIAVVK7
#     Adding 36 records...
# New cache has 164402 records, saving.
# 667402 :done!
# Using cache
# Using 117616 records from cache
# Loading from http://thingspeak.com/channels/667406/feeds/entry/117617.json?api_key=1K40QAHJQLR3R6HB
# Loading from http://thingspeak.com/channels/667406/feeds.json?start=2019-10-10T06:56:27Z&end=2019-10-10T06:57:07Z&api_key=1K40QAHJQLR3R6HB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/667406/feeds/entry/125616.json?api_key=1K40QAHJQLR3R6HB
# Loading from http://thingspeak.com/channels/667406/feeds.json?start=2019-10-10T06:57:08Z&end=2019-10-10T10:23:07Z&api_key=1K40QAHJQLR3R6HB
#     Adding 43 records...
# New cache has 117659 records, saving.
# 667406 :done!
# Using cache
# Using 77133 records from cache
# Loading from http://thingspeak.com/channels/672528/feeds/entry/77134.json?api_key=YOW5ITSXCLW7IA0C
# Loading from http://thingspeak.com/channels/672528/feeds.json?start=2019-10-09T23:31:32Z&end=2019-10-10T10:23:15Z&api_key=YOW5ITSXCLW7IA0C
#     Adding 0 records...
# New cache has 77133 records, saving.
# 672528 :done!
# Using cache
# Using 195344 records from cache
# Loading from http://thingspeak.com/channels/675740/feeds/entry/195345.json?api_key=H3EY1WFQK4M2C2ZP
# Loading from http://thingspeak.com/channels/675740/feeds.json?start=2019-10-10T06:56:53Z&end=2019-10-10T06:58:07Z&api_key=H3EY1WFQK4M2C2ZP
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675740/feeds/entry/203344.json?api_key=H3EY1WFQK4M2C2ZP
# Loading from http://thingspeak.com/channels/675740/feeds.json?start=2019-10-10T06:58:08Z&end=2019-10-10T10:23:33Z&api_key=H3EY1WFQK4M2C2ZP
#     Adding 12 records...
# New cache has 195356 records, saving.
# 675740 :done!
# Using cache
# Using 214748 records from cache
# Loading from http://thingspeak.com/channels/675801/feeds/entry/214749.json?api_key=0T0B4DV3ZXBIGF7L
# Loading from http://thingspeak.com/channels/675801/feeds.json?start=2019-10-10T06:56:23Z&end=2019-10-10T06:57:50Z&api_key=0T0B4DV3ZXBIGF7L
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675801/feeds/entry/222748.json?api_key=0T0B4DV3ZXBIGF7L
# Loading from http://thingspeak.com/channels/675801/feeds.json?start=2019-10-10T06:57:51Z&end=2019-10-10T10:23:54Z&api_key=0T0B4DV3ZXBIGF7L
#     Adding 20 records...
# New cache has 214768 records, saving.
# 675801 :done!
# Using cache
# Using 233288 records from cache
# Loading from http://thingspeak.com/channels/675805/feeds/entry/233289.json?api_key=T7I8LW37U46H7L9L
# Loading from http://thingspeak.com/channels/675805/feeds.json?start=2019-10-09T18:17:13Z&end=2019-10-10T10:24:06Z&api_key=T7I8LW37U46H7L9L
#     Adding 0 records...
# New cache has 233288 records, saving.
# 675805 :done!
# Using cache
# Using 204889 records from cache
# Loading from http://thingspeak.com/channels/675851/feeds/entry/204890.json?api_key=UJDHKVXFA7MCWUIN
# Loading from http://thingspeak.com/channels/675851/feeds.json?start=2019-10-10T06:57:33Z&end=2019-10-10T06:58:52Z&api_key=UJDHKVXFA7MCWUIN
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675851/feeds/entry/212889.json?api_key=UJDHKVXFA7MCWUIN
# Loading from http://thingspeak.com/channels/675851/feeds.json?start=2019-10-10T06:58:53Z&end=2019-10-10T10:24:24Z&api_key=UJDHKVXFA7MCWUIN
#     Adding 19 records...
# New cache has 204908 records, saving.
# 675851 :done!
# Using cache
# Using 172508 records from cache
# Loading from http://thingspeak.com/channels/675991/feeds/entry/172509.json?api_key=WIK7QY0GKOYZFYB6
# Loading from http://thingspeak.com/channels/675991/feeds.json?start=2019-10-10T06:58:14Z&end=2019-10-10T06:59:27Z&api_key=WIK7QY0GKOYZFYB6
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/675991/feeds/entry/180508.json?api_key=WIK7QY0GKOYZFYB6
# Loading from http://thingspeak.com/channels/675991/feeds.json?start=2019-10-10T06:59:28Z&end=2019-10-10T10:24:46Z&api_key=WIK7QY0GKOYZFYB6
#     Adding 11 records...
# New cache has 172519 records, saving.
# 675991 :done!
# Using cache
# Using 221338 records from cache
# Loading from http://thingspeak.com/channels/676000/feeds/entry/221339.json?api_key=R1UWA4NKVLEWRT8A
# Loading from http://thingspeak.com/channels/676000/feeds.json?start=2019-10-08T15:58:00Z&end=2019-10-10T10:25:01Z&api_key=R1UWA4NKVLEWRT8A
#     Adding 0 records...
# New cache has 221338 records, saving.
# 676000 :done!
# Using cache
# Using 5567 records from cache
# Loading from http://thingspeak.com/channels/689508/feeds/entry/5568.json?api_key=W3TREK1FFIFCQET6
# Loading from http://thingspeak.com/channels/689508/feeds.json?start=2019-06-14T08:21:30Z&end=2019-10-10T10:25:11Z&api_key=W3TREK1FFIFCQET6
#     Adding 0 records...
# New cache has 5567 records, saving.
# 689508 :done!
# Using cache
# Using 58445 records from cache
# Loading from http://thingspeak.com/channels/689511/feeds/entry/58446.json?api_key=GZMTUYFZ3WKL09DA
# Loading from http://thingspeak.com/channels/689511/feeds.json?start=2019-08-04T13:35:48Z&end=2019-10-10T10:25:16Z&api_key=GZMTUYFZ3WKL09DA
#     Adding 0 records...
# New cache has 58445 records, saving.
# 689511 :done!
# Using cache
# Using 182030 records from cache
# Loading from http://thingspeak.com/channels/689516/feeds/entry/182031.json?api_key=N6OC9S4QP5R26D38
# Loading from http://thingspeak.com/channels/689516/feeds.json?start=2019-10-10T06:58:38Z&end=2019-10-10T07:00:06Z&api_key=N6OC9S4QP5R26D38
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689516/feeds/entry/190030.json?api_key=N6OC9S4QP5R26D38
# Loading from http://thingspeak.com/channels/689516/feeds.json?start=2019-10-10T07:00:07Z&end=2019-10-10T10:25:30Z&api_key=N6OC9S4QP5R26D38
#     Adding 19 records...
# New cache has 182049 records, saving.
# 689516 :done!
# Using cache
# Using 116316 records from cache
# Loading from http://thingspeak.com/channels/689518/feeds/entry/116317.json?api_key=SP661YXSYJLE091E
# Loading from http://thingspeak.com/channels/689518/feeds.json?start=2019-10-09T14:52:11Z&end=2019-10-10T10:25:41Z&api_key=SP661YXSYJLE091E
#     Adding 0 records...
# New cache has 116316 records, saving.
# 689518 :done!
# Using cache
# Using 98525 records from cache
# Loading from http://thingspeak.com/channels/689520/feeds/entry/98526.json?api_key=LUY3VEB20UIE4G1I
# Loading from http://thingspeak.com/channels/689520/feeds.json?start=2019-10-10T06:59:24Z&end=2019-10-10T07:00:36Z&api_key=LUY3VEB20UIE4G1I
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689520/feeds/entry/106525.json?api_key=LUY3VEB20UIE4G1I
# Loading from http://thingspeak.com/channels/689520/feeds.json?start=2019-10-10T07:00:37Z&end=2019-10-10T10:26:01Z&api_key=LUY3VEB20UIE4G1I
#     Adding 19 records...
# New cache has 98544 records, saving.
# 689520 :done!
# Using cache
# Using 165015 records from cache
# Loading from http://thingspeak.com/channels/689522/feeds/entry/165016.json?api_key=KRK2MEGVMD22YY59
# Loading from http://thingspeak.com/channels/689522/feeds.json?start=2019-10-10T07:00:22Z&end=2019-10-10T07:01:41Z&api_key=KRK2MEGVMD22YY59
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689522/feeds/entry/173015.json?api_key=KRK2MEGVMD22YY59
# Loading from http://thingspeak.com/channels/689522/feeds.json?start=2019-10-10T07:01:42Z&end=2019-10-10T10:26:15Z&api_key=KRK2MEGVMD22YY59
#     Adding 19 records...
# New cache has 165034 records, saving.
# 689522 :done!
# Using cache
# Using 115857 records from cache
# Loading from http://thingspeak.com/channels/689525/feeds/entry/115858.json?api_key=NWFG4DF3K0KEYT15
# Loading from http://thingspeak.com/channels/689525/feeds.json?start=2019-10-10T07:00:23Z&end=2019-10-10T07:01:42Z&api_key=NWFG4DF3K0KEYT15
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689525/feeds/entry/123857.json?api_key=NWFG4DF3K0KEYT15
# Loading from http://thingspeak.com/channels/689525/feeds.json?start=2019-10-10T07:01:43Z&end=2019-10-10T10:26:33Z&api_key=NWFG4DF3K0KEYT15
#     Adding 19 records...
# New cache has 115876 records, saving.
# 689525 :done!
# Using cache
# Using 110344 records from cache
# Loading from http://thingspeak.com/channels/689530/feeds/entry/110345.json?api_key=9FWEYOXMJHJG0PEB
# Loading from http://thingspeak.com/channels/689530/feeds.json?start=2019-10-10T07:00:51Z&end=2019-10-10T07:02:01Z&api_key=9FWEYOXMJHJG0PEB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689530/feeds/entry/118344.json?api_key=9FWEYOXMJHJG0PEB
# Loading from http://thingspeak.com/channels/689530/feeds.json?start=2019-10-10T07:02:02Z&end=2019-10-10T10:26:49Z&api_key=9FWEYOXMJHJG0PEB
#     Adding 20 records...
# New cache has 110364 records, saving.
# 689530 :done!
# Using cache
# Using 59433 records from cache
# Loading from http://thingspeak.com/channels/689532/feeds/entry/59434.json?api_key=2GGXH0YLJC992BLG
# Loading from http://thingspeak.com/channels/689532/feeds.json?start=2019-06-28T14:49:55Z&end=2019-10-10T10:26:56Z&api_key=2GGXH0YLJC992BLG
#     Adding 0 records...
# New cache has 59433 records, saving.
# 689532 :done!
# Using cache
# Using 146844 records from cache
# Loading from http://thingspeak.com/channels/689749/feeds/entry/146845.json?api_key=1CF1BEEI1OJ67E3H
# Loading from http://thingspeak.com/channels/689749/feeds.json?start=2019-10-06T10:10:47Z&end=2019-10-10T10:27:02Z&api_key=1CF1BEEI1OJ67E3H
#     Adding 0 records...
# New cache has 146844 records, saving.
# 689749 :done!
# Using cache
# Using 181822 records from cache
# Loading from http://thingspeak.com/channels/689750/feeds/entry/181823.json?api_key=LWGIC3U8ZR004J04
# Loading from http://thingspeak.com/channels/689750/feeds.json?start=2019-10-10T07:00:24Z&end=2019-10-10T07:01:38Z&api_key=LWGIC3U8ZR004J04
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689750/feeds/entry/189822.json?api_key=LWGIC3U8ZR004J04
# Loading from http://thingspeak.com/channels/689750/feeds.json?start=2019-10-10T07:01:39Z&end=2019-10-10T10:27:25Z&api_key=LWGIC3U8ZR004J04
#     Adding 20 records...
# New cache has 181842 records, saving.
# 689750 :done!
# Using cache
# Using 58901 records from cache
# Loading from http://thingspeak.com/channels/689752/feeds/entry/58902.json?api_key=98KV1E257QS3SASB
# Loading from http://thingspeak.com/channels/689752/feeds.json?start=2019-09-26T09:27:06Z&end=2019-10-10T10:27:36Z&api_key=98KV1E257QS3SASB
#     Adding 0 records...
# New cache has 58901 records, saving.
# 689752 :done!
# Using cache
# Using 104994 records from cache
# Loading from http://thingspeak.com/channels/689753/feeds/entry/104995.json?api_key=1FL0QL9OTDMN9T33
# Loading from http://thingspeak.com/channels/689753/feeds.json?start=2019-10-10T07:01:21Z&end=2019-10-10T07:02:36Z&api_key=1FL0QL9OTDMN9T33
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689753/feeds/entry/112994.json?api_key=1FL0QL9OTDMN9T33
# Loading from http://thingspeak.com/channels/689753/feeds.json?start=2019-10-10T07:02:37Z&end=2019-10-10T10:27:46Z&api_key=1FL0QL9OTDMN9T33
#     Adding 20 records...
# New cache has 105014 records, saving.
# 689753 :done!
# Using cache
# Using 166032 records from cache
# Loading from http://thingspeak.com/channels/689756/feeds/entry/166033.json?api_key=EIVEW4EZHD38VLN7
# Loading from http://thingspeak.com/channels/689756/feeds.json?start=2019-10-10T07:01:11Z&end=2019-10-10T07:02:38Z&api_key=EIVEW4EZHD38VLN7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689756/feeds/entry/174032.json?api_key=EIVEW4EZHD38VLN7
# Loading from http://thingspeak.com/channels/689756/feeds.json?start=2019-10-10T07:02:39Z&end=2019-10-10T10:28:08Z&api_key=EIVEW4EZHD38VLN7
#     Adding 19 records...
# New cache has 166051 records, saving.
# 689756 :done!
# Using cache
# Using 152027 records from cache
# Loading from http://thingspeak.com/channels/689759/feeds/entry/152028.json?api_key=FG9PD1OUD9OLGZB3
# Loading from http://thingspeak.com/channels/689759/feeds.json?start=2019-10-02T14:58:14Z&end=2019-10-10T10:28:16Z&api_key=FG9PD1OUD9OLGZB3
#     Adding 0 records...
# New cache has 152027 records, saving.
# 689759 :done!
# Using cache
# Using 207799 records from cache
# Loading from http://thingspeak.com/channels/689761/feeds/entry/207800.json?api_key=YEGZIVUS16X2R4BO
# Loading from http://thingspeak.com/channels/689761/feeds.json?start=2019-10-10T07:01:57Z&end=2019-10-10T07:03:13Z&api_key=YEGZIVUS16X2R4BO
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689761/feeds/entry/215799.json?api_key=YEGZIVUS16X2R4BO
# Loading from http://thingspeak.com/channels/689761/feeds.json?start=2019-10-10T07:03:14Z&end=2019-10-10T10:28:29Z&api_key=YEGZIVUS16X2R4BO
#     Adding 20 records...
# New cache has 207819 records, saving.
# 689761 :done!
# Using cache
# Using 63855 records from cache
# Loading from http://thingspeak.com/channels/689766/feeds/entry/63856.json?api_key=3XTH7YLBLURX0XQB
# Loading from http://thingspeak.com/channels/689766/feeds.json?start=2019-10-09T20:08:43Z&end=2019-10-10T07:14:07Z&api_key=3XTH7YLBLURX0XQB
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/689766/feeds/entry/71855.json?api_key=3XTH7YLBLURX0XQB
# Loading from http://thingspeak.com/channels/689766/feeds.json?start=2019-10-10T07:14:08Z&end=2019-10-10T10:28:40Z&api_key=3XTH7YLBLURX0XQB
#     Adding 3 records...
# New cache has 63858 records, saving.
# 689766 :done!
# Using cache
# Using 16981 records from cache
# Loading from http://thingspeak.com/channels/689768/feeds/entry/16982.json?api_key=IKZL0YTFYDWN701G
# Loading from http://thingspeak.com/channels/689768/feeds.json?start=2019-04-27T20:35:31Z&end=2019-10-10T10:28:46Z&api_key=IKZL0YTFYDWN701G
#     Adding 0 records...
# New cache has 16981 records, saving.
# 689768 :done!
# Using cache
# Using 207289 records from cache
# Loading from http://thingspeak.com/channels/718028/feeds/entry/207290.json?api_key=HNTV5QEJTD8RTG2H
# Loading from http://thingspeak.com/channels/718028/feeds.json?start=2019-10-10T07:02:12Z&end=2019-10-10T07:03:25Z&api_key=HNTV5QEJTD8RTG2H
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718028/feeds/entry/215289.json?api_key=HNTV5QEJTD8RTG2H
# Loading from http://thingspeak.com/channels/718028/feeds.json?start=2019-10-10T07:03:26Z&end=2019-10-10T10:28:54Z&api_key=HNTV5QEJTD8RTG2H
#     Adding 20 records...
# New cache has 207309 records, saving.
# 718028 :done!
# Using cache
# Using 185033 records from cache
# Loading from http://thingspeak.com/channels/718029/feeds/entry/185034.json?api_key=TRF8VHH9DWUKBT59
# Loading from http://thingspeak.com/channels/718029/feeds.json?start=2019-10-10T07:03:30Z&end=2019-10-10T07:04:45Z&api_key=TRF8VHH9DWUKBT59
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718029/feeds/entry/193033.json?api_key=TRF8VHH9DWUKBT59
# Loading from http://thingspeak.com/channels/718029/feeds.json?start=2019-10-10T07:04:46Z&end=2019-10-10T10:29:07Z&api_key=TRF8VHH9DWUKBT59
#     Adding 19 records...
# New cache has 185052 records, saving.
# 718029 :done!
# Using cache
# Using 198042 records from cache
# Loading from http://thingspeak.com/channels/718030/feeds/entry/198043.json?api_key=2VDX6R4QQY92HH7A
# Loading from http://thingspeak.com/channels/718030/feeds.json?start=2019-10-10T07:02:44Z&end=2019-10-10T07:04:07Z&api_key=2VDX6R4QQY92HH7A
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/718030/feeds/entry/206042.json?api_key=2VDX6R4QQY92HH7A
# Loading from http://thingspeak.com/channels/718030/feeds.json?start=2019-10-10T07:04:08Z&end=2019-10-10T10:29:20Z&api_key=2VDX6R4QQY92HH7A
#     Adding 20 records...
# New cache has 198062 records, saving.
# 718030 :done!
# Using cache
# Using 183953 records from cache
# Loading from http://thingspeak.com/channels/730014/feeds/entry/183954.json?api_key=8A9OOESUKHXIE80Z
# Loading from http://thingspeak.com/channels/730014/feeds.json?start=2019-10-10T07:03:16Z&end=2019-10-10T07:04:30Z&api_key=8A9OOESUKHXIE80Z
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730014/feeds/entry/191953.json?api_key=8A9OOESUKHXIE80Z
# Loading from http://thingspeak.com/channels/730014/feeds.json?start=2019-10-10T07:04:31Z&end=2019-10-10T10:29:32Z&api_key=8A9OOESUKHXIE80Z
#     Adding 20 records...
# New cache has 183973 records, saving.
# 730014 :done!
# Using cache
# Using 191788 records from cache
# Loading from http://thingspeak.com/channels/730015/feeds/entry/191789.json?api_key=IWDN2EZTU4IA2ZPW
# Loading from http://thingspeak.com/channels/730015/feeds.json?start=2019-10-10T07:04:10Z&end=2019-10-10T07:05:33Z&api_key=IWDN2EZTU4IA2ZPW
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730015/feeds/entry/199788.json?api_key=IWDN2EZTU4IA2ZPW
# Loading from http://thingspeak.com/channels/730015/feeds.json?start=2019-10-10T07:05:34Z&end=2019-10-10T10:29:45Z&api_key=IWDN2EZTU4IA2ZPW
#     Adding 19 records...
# New cache has 191807 records, saving.
# 730015 :done!
# Using cache
# Using 170450 records from cache
# Loading from http://thingspeak.com/channels/730016/feeds/entry/170451.json?api_key=C5HH5TN5WK8TPQOQ
# Loading from http://thingspeak.com/channels/730016/feeds.json?start=2019-10-10T07:04:35Z&end=2019-10-10T07:06:02Z&api_key=C5HH5TN5WK8TPQOQ
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/730016/feeds/entry/178450.json?api_key=C5HH5TN5WK8TPQOQ
# Loading from http://thingspeak.com/channels/730016/feeds.json?start=2019-10-10T07:06:03Z&end=2019-10-10T10:29:57Z&api_key=C5HH5TN5WK8TPQOQ
#     Adding 18 records...
# New cache has 170468 records, saving.
# 730016 :done!
# Using cache
# Using 167697 records from cache
# Loading from http://thingspeak.com/channels/730019/feeds/entry/167698.json?api_key=Y1VA42KWZFE7MJDZ
# Loading from http://thingspeak.com/channels/730019/feeds.json?start=2019-10-09T18:02:59Z&end=2019-10-10T10:30:06Z&api_key=Y1VA42KWZFE7MJDZ
#     Adding 0 records...
# New cache has 167697 records, saving.
# 730019 :done!
# Using cache
# Using 148066 records from cache
# Loading from http://thingspeak.com/channels/737273/feeds/entry/148067.json?api_key=5QFKQIGSKJK517SZ
# Loading from http://thingspeak.com/channels/737273/feeds.json?start=2019-10-07T18:14:29Z&end=2019-10-10T10:30:18Z&api_key=5QFKQIGSKJK517SZ
#     Adding 0 records...
# New cache has 148066 records, saving.
# 737273 :done!
# Using cache
# Using 35037 records from cache
# Loading from http://thingspeak.com/channels/737274/feeds/entry/35038.json?api_key=UX5TORPRJKXR3YZ1
# Loading from http://thingspeak.com/channels/737274/feeds.json?start=2019-06-11T05:48:12Z&end=2019-10-10T10:30:29Z&api_key=UX5TORPRJKXR3YZ1
#     Adding 0 records...
# New cache has 35037 records, saving.
# 737274 :done!
# Using cache
# Using 22183 records from cache
# Loading from http://thingspeak.com/channels/737275/feeds/entry/22184.json?api_key=0TVL12ZFTQXQJACL
# Loading from http://thingspeak.com/channels/737275/feeds.json?start=2019-07-04T17:18:52Z&end=2019-10-10T10:30:45Z&api_key=0TVL12ZFTQXQJACL
#     Adding 0 records...
# New cache has 22183 records, saving.
# 737275 :done!
# Using cache
# Using 189145 records from cache
# Loading from http://thingspeak.com/channels/737276/feeds/entry/189146.json?api_key=VHE2PZCJLMYHB7ZI
# Loading from http://thingspeak.com/channels/737276/feeds.json?start=2019-10-10T07:06:15Z&end=2019-10-10T07:07:38Z&api_key=VHE2PZCJLMYHB7ZI
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/737276/feeds/entry/197145.json?api_key=VHE2PZCJLMYHB7ZI
# Loading from http://thingspeak.com/channels/737276/feeds.json?start=2019-10-10T07:07:39Z&end=2019-10-10T10:31:58Z&api_key=VHE2PZCJLMYHB7ZI
#     Adding 19 records...
# New cache has 189164 records, saving.
# 737276 :done!
# Using cache
# Using 154359 records from cache
# Loading from http://thingspeak.com/channels/737278/feeds/entry/154360.json?api_key=U0PR0AUGQU2K5JQC
# Loading from http://thingspeak.com/channels/737278/feeds.json?start=2019-10-10T07:06:46Z&end=2019-10-10T07:08:01Z&api_key=U0PR0AUGQU2K5JQC
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/737278/feeds/entry/162359.json?api_key=U0PR0AUGQU2K5JQC
# Loading from http://thingspeak.com/channels/737278/feeds.json?start=2019-10-10T07:08:02Z&end=2019-10-10T10:33:15Z&api_key=U0PR0AUGQU2K5JQC
#     Adding 20 records...
# New cache has 154379 records, saving.
# 737278 :done!
# Using cache
# Using 153387 records from cache
# Loading from http://thingspeak.com/channels/755609/feeds/entry/153388.json?api_key=BI5JRX3TJ8LTWLU0
# Loading from http://thingspeak.com/channels/755609/feeds.json?start=2019-10-10T07:08:00Z&end=2019-10-10T07:09:18Z&api_key=BI5JRX3TJ8LTWLU0
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/755609/feeds/entry/161387.json?api_key=BI5JRX3TJ8LTWLU0
# Loading from http://thingspeak.com/channels/755609/feeds.json?start=2019-10-10T07:09:19Z&end=2019-10-10T10:33:29Z&api_key=BI5JRX3TJ8LTWLU0
#     Adding 19 records...
# New cache has 153406 records, saving.
# 755609 :done!
# Using cache
# Using 7571 records from cache
# Loading from http://thingspeak.com/channels/755610/feeds/entry/7572.json?api_key=YPB4XZHBPI1MA358
# Loading from http://thingspeak.com/channels/755610/feeds.json?start=2019-05-21T12:01:55Z&end=2019-10-10T10:33:38Z&api_key=YPB4XZHBPI1MA358
#     Adding 0 records...
# New cache has 7571 records, saving.
# 755610 :done!
# Using cache
# Using 130890 records from cache
# Loading from http://thingspeak.com/channels/755612/feeds/entry/130891.json?api_key=AZ3Q42XK8FOUF8P7
# Loading from http://thingspeak.com/channels/755612/feeds.json?start=2019-10-10T07:08:42Z&end=2019-10-10T07:10:00Z&api_key=AZ3Q42XK8FOUF8P7
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/755612/feeds/entry/138890.json?api_key=AZ3Q42XK8FOUF8P7
# Loading from http://thingspeak.com/channels/755612/feeds.json?start=2019-10-10T07:10:01Z&end=2019-10-10T10:33:48Z&api_key=AZ3Q42XK8FOUF8P7
#     Adding 18 records...
# New cache has 130908 records, saving.
# 755612 :done!
# Using cache
# Using 133572 records from cache
# Loading from http://thingspeak.com/channels/755614/feeds/entry/133573.json?api_key=NZE1II9NGDOMN3BS
# Loading from http://thingspeak.com/channels/755614/feeds.json?start=2019-10-04T14:12:45Z&end=2019-10-04T14:13:59Z&api_key=NZE1II9NGDOMN3BS
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/755614/feeds/entry/141572.json?api_key=NZE1II9NGDOMN3BS
# Loading from http://thingspeak.com/channels/755614/feeds.json?start=2019-10-04T14:14:00Z&end=2019-10-10T10:34:01Z&api_key=NZE1II9NGDOMN3BS
#     Adding 6341 records...
# New cache has 139913 records, saving.
# 755614 :done!
# Using cache
# Using 81385 records from cache
# Loading from http://thingspeak.com/channels/782718/feeds/entry/81386.json?api_key=Q5UUO172BQ33X8S1
# Loading from http://thingspeak.com/channels/782718/feeds.json?start=2019-10-04T14:12:25Z&end=2019-10-04T14:13:40Z&api_key=Q5UUO172BQ33X8S1
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782718/feeds/entry/89385.json?api_key=Q5UUO172BQ33X8S1
# Loading from http://thingspeak.com/channels/782718/feeds.json?start=2019-10-04T14:13:41Z&end=2019-10-10T10:34:35Z&api_key=Q5UUO172BQ33X8S1
#     Adding 2795 records...
# New cache has 84180 records, saving.
# 782718 :done!
# Using cache
# Using 114156 records from cache
# Loading from http://thingspeak.com/channels/782719/feeds/entry/114157.json?api_key=QTNAHITKHEJ4C9I5
# Loading from http://thingspeak.com/channels/782719/feeds.json?start=2019-10-04T14:12:20Z&end=2019-10-04T14:13:46Z&api_key=QTNAHITKHEJ4C9I5
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782719/feeds/entry/122156.json?api_key=QTNAHITKHEJ4C9I5
# Loading from http://thingspeak.com/channels/782719/feeds.json?start=2019-10-04T14:13:47Z&end=2019-10-10T10:34:53Z&api_key=QTNAHITKHEJ4C9I5
#     Adding 5221 records...
# New cache has 119377 records, saving.
# 782719 :done!
# Using cache
# Using 91811 records from cache
# Loading from http://thingspeak.com/channels/782720/feeds/entry/91812.json?api_key=7ZN35W0OYQQ1A2ZC
# Loading from http://thingspeak.com/channels/782720/feeds.json?start=2019-10-04T14:13:05Z&end=2019-10-04T14:14:31Z&api_key=7ZN35W0OYQQ1A2ZC
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782720/feeds/entry/99811.json?api_key=7ZN35W0OYQQ1A2ZC
# Loading from http://thingspeak.com/channels/782720/feeds.json?start=2019-10-04T14:14:32Z&end=2019-10-10T10:35:16Z&api_key=7ZN35W0OYQQ1A2ZC
#     Adding 4219 records...
# New cache has 96030 records, saving.
# 782720 :done!
# Using cache
# Using 100621 records from cache
# Loading from http://thingspeak.com/channels/782721/feeds/entry/100622.json?api_key=QU3CSDCF0X5X1S06
# Loading from http://thingspeak.com/channels/782721/feeds.json?start=2019-10-04T14:09:10Z&end=2019-10-04T14:16:35Z&api_key=QU3CSDCF0X5X1S06
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782721/feeds/entry/108621.json?api_key=QU3CSDCF0X5X1S06
# Loading from http://thingspeak.com/channels/782721/feeds.json?start=2019-10-04T14:16:36Z&end=2019-10-10T10:36:02Z&api_key=QU3CSDCF0X5X1S06
#     Adding 4289 records...
# New cache has 104910 records, saving.
# 782721 :done!
# Using cache
# Using 87074 records from cache
# Loading from http://thingspeak.com/channels/782722/feeds/entry/87075.json?api_key=OGG3UX99KTA41C1K
# Loading from http://thingspeak.com/channels/782722/feeds.json?start=2019-10-04T13:08:08Z&end=2019-10-04T21:01:37Z&api_key=OGG3UX99KTA41C1K
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/782722/feeds/entry/95074.json?api_key=OGG3UX99KTA41C1K
# Loading from http://thingspeak.com/channels/782722/feeds.json?start=2019-10-04T21:01:38Z&end=2019-10-10T10:37:02Z&api_key=OGG3UX99KTA41C1K
#     Adding 3999 records...
# New cache has 91073 records, saving.
# 782722 :done!
# Using cache
# Using 58 records from cache
# Loading from http://thingspeak.com/channels/782723/feeds/entry/59.json?api_key=DNB8Q1WI3PO7000T
# Loading from http://thingspeak.com/channels/782723/feeds.json?start=2019-07-24T11:19:35Z&end=2019-10-10T10:38:09Z&api_key=DNB8Q1WI3PO7000T
#     Adding 0 records...
# New cache has 58 records, saving.
# 782723 :done!
# Using cache
# Using 61303 records from cache
# Loading from http://thingspeak.com/channels/832251/feeds/entry/61304.json?api_key=LRAC4HSQ3H0JSUW4
# Loading from http://thingspeak.com/channels/832251/feeds.json?start=2019-10-04T14:13:46Z&end=2019-10-04T14:15:04Z&api_key=LRAC4HSQ3H0JSUW4
#     Adding 0 records...
# Loading from http://thingspeak.com/channels/832251/feeds/entry/69303.json?api_key=LRAC4HSQ3H0JSUW4
# Loading from http://thingspeak.com/channels/832251/feeds.json?start=2019-10-04T14:15:05Z&end=2019-10-10T10:38:23Z&api_key=LRAC4HSQ3H0JSUW4
#     Adding 5572 records...
# New cache has 66875 records, saving.
# 832251 :done!
# Using cache
# Using 111013 records from cache
# Loading from http://thingspeak.com/channels/742703/feeds/entry/111014.json?api_key=MSHOGX6N0EYY140G
# Loading from http://thingspeak.com/channels/742703/feeds.json?start=2019-05-26T08:13:37Z&end=2019-10-10T10:40:47Z&api_key=MSHOGX6N0EYY140G
#     Adding 0 records...
# New cache has 111013 records, saving.
# 742703 :done!
# Using cache
# Using 153905 records from cache
# Loading from http://thingspeak.com/channels/741339/feeds/entry/153906.json?api_key=LY78C6EEGO3RT04V
# Loading from http://thingspeak.com/channels/741339/feeds.json?start=2019-09-25T11:45:04Z&end=2019-10-10T10:40:58Z&api_key=LY78C6EEGO3RT04V
#     Adding 0 records...
# New cache has 153905 records, saving.
# 741339 :done!
# Using cache
# Using 43068 records from cache
# Loading from http://thingspeak.com/channels/741341/feeds/entry/43069.json?api_key=HUDSTF69DDZM7IPP
# Loading from http://thingspeak.com/channels/741341/feeds.json?start=2019-03-05T20:53:04Z&end=2019-10-10T10:41:33Z&api_key=HUDSTF69DDZM7IPP
#     Adding 0 records...
# New cache has 43068 records, saving.
# 741341 :done!
# Using cache
# Using 15993 records from cache
# Loading from http://thingspeak.com/channels/741342/feeds/entry/15994.json?api_key=5MSX75QS74WTEOSD
# Loading from http://thingspeak.com/channels/741342/feeds.json?start=2019-09-19T10:24:14Z&end=2019-10-10T10:41:47Z&api_key=5MSX75QS74WTEOSD
#     Adding 0 records...
# New cache has 15993 records, saving.
# 741342 :done!

# %%
channel_data_list[0].head()
# Out:
#                  created_at  entry_id    field1    field2    field3    field4  \
# 0 2018-12-05 14:17:49+03:00         1     11.97     18.11     24.15      1.39
# 1 2018-12-05 14:18:49+03:00         2      5.67      7.58      9.33      1.39
# 2 2018-12-05 14:19:47+03:00         3      4.83      6.29      7.15      1.39
# 3 2018-12-05 14:20:44+03:00         4      5.11      6.68      9.56      1.39
# 4 2018-12-05 14:21:44+03:00         5      4.91      6.44      8.59      1.39
#
#         field5       field6    field7 field8 channel_id
# 0     0.000000     0.000000      3.91   None     643676
# 1  1000.000000  1000.000000      3.93   None     643676
# 2  1000.000000  1000.000000      3.93   None     643676
# 3  1000.000000  1000.000000      3.94   None     643676
# 4  1000.000000  1000.000000      3.94   None     643676

# %%
#Column names for the different types of sensors
PMS_heads_7 = ['time', 'entry_id', 'pm2_5', 'pm10', 's2_pm2_5', 's2_pm10', 'lat', 'long', 'voltage', 'channel_id']
PMS_heads_8 = ['time', 'entry_id', 'pm2_5', 'pm10', 's2_pm2_5', 's2_pm10', 'lat', 'long', 'voltage', 'gps_data', 'channel_id']
OPC_N2_heads_7 = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'sample_period', 'lat', 'long', 'voltage', 'channel_id']
OPC_N2_heads_8 = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'sample_period', 'lat', 'long', 'voltage', 'gps_data', 'channel_id']
PA_heads = ['time', 'entry_id', 'pm1', 'pm2_5', 'pm10', 'uptime', 'RSSI', 'temp', 'humidity', 'pm2_5_cf1', 'channel_id']

# %%
# creating a dictionary of the csv file names and their respective csv files
channel_name_dict = dict(zip(channel_metadata['channel_name'], channel_data_list)) #where keys=filenames and values=dataframes

# %%
# Setting the column names for the different csv files based on the file name
for filename, dataframe in channel_name_dict.items():
                    
    rows,columns = dataframe.shape
    
    if (('AQ_' in filename) and (columns==11)):
        channel_name_dict[filename].columns = PMS_heads_8
        print (filename, ': PMS_heads_8')
            
    elif(('AQ_' in filename) and (columns==10)):
        channel_name_dict[filename].columns = PMS_heads_7  
        print (filename, ': PMS_heads_7')
            
    elif ('PA' in filename):
        channel_name_dict[filename].columns = PA_heads
        print (filename, ': PA')            
            
    elif (('8A' in filename) or ('6F' in filename)):
        channel_name_dict[filename].columns = OPC_N2_heads_8   
        print (filename, ': 8A/6F')
            
    else:
        channel_name_dict[filename].columns = OPC_N2_heads_7
        print (filename, ': the rest')
# Out:
# AQ_01 : PMS_heads_8
# AQ_02 : PMS_heads_7
# AQ_03 : PMS_heads_7
# AQ_04 : PMS_heads_8
# AQ_05 : PMS_heads_8
# AQ_06 : PMS_heads_8
# AQ_07 : PMS_heads_8
# AQ_08 : PMS_heads_8
# AQ_09 : PMS_heads_8
# AQ_10 : PMS_heads_8
# AQ_11 : PMS_heads_8
# AQ_12 : PMS_heads_8
# AQ_13 : PMS_heads_8
# AQ_14 : PMS_heads_8
# AQ_15 : PMS_heads_8
# AQ_16 : PMS_heads_8
# AQ_17 : PMS_heads_8
# AQ_18 : PMS_heads_8
# AQ_19 : PMS_heads_8
# AQ_20 : PMS_heads_8
# AQ_21 : PMS_heads_8
# AQ_22 : PMS_heads_8
# AQ_23 : PMS_heads_8
# AQ_24 : PMS_heads_8
# AQ_25 : PMS_heads_8
# AQ_26 : PMS_heads_8
# AQ_27 : PMS_heads_8
# AQ_28 : PMS_heads_8
# AQ_29 : PMS_heads_8
# AQ_30 : PMS_heads_8
# AQ_31 : PMS_heads_8
# AQ_32 : PMS_heads_8
# AQ_33 : PMS_heads_8
# AQ_34 : PMS_heads_8
# AQ_35 : PMS_heads_8
# AQ_36 : PMS_heads_8
# AQ_37 : PMS_heads_8
# AQ_38 : PMS_heads_8
# AQ_39 : PMS_heads_8
# AQ_40 : PMS_heads_8
# AQ_41 : PMS_heads_8
# AQ_42 : PMS_heads_8
# AQ_43 : PMS_heads_8
# AQ_44 : PMS_heads_8
# AQ_45 : PMS_heads_8
# AQ_46 : PMS_heads_8
# AQ_47 : PMS_heads_8
# AQ_48 : PMS_heads_8
# AQ_49 : PMS_heads_8
# AQ_50 : PMS_heads_8
# AQ_51 : PMS_heads_8
# PA_01 : PA
# PA_02 : PA
# PA_03 : PA
# PA_04 : PA

# %%
#Adding latitude and longitude coordinates for Purple Air Sensors
for filename, dataframe in channel_name_dict.items():
    if ('PA_01' in filename): #International School Lubowa
        dataframe['lat'] = 0.2357
        dataframe['long'] = 32.5576
        #print (dataframe.head())
    elif ('PA_02' in filename): #Makerere
        dataframe['lat'] = 0.332050  #estimates
        dataframe['long'] = 32.570509
    elif ('PA_03' in filename): #Kabale
        dataframe['lat'] = -1.245 
        dataframe['long'] = 29.9892
    elif ('PA_04' in filename): #Bunamwaya
        dataframe['lat'] = 0.27
        dataframe['long'] = 32.558

channel_name_dict['PA_01'].head()
# Out:
#                        time  entry_id  pm1 pm2_5  pm10 uptime RSSI temp  \
# 0 2018-11-23 21:01:29+03:00         1    0     0     0      1  -48   55
# 1 2018-11-23 21:02:49+03:00         2    0   0.2  0.67      3  -51   56
# 2 2018-11-23 21:04:09+03:00         3    0   0.4  0.42      4  -59   56
# 3 2018-11-23 21:05:29+03:00         4    0  0.47  0.94      5  -60   57
# 4 2018-11-23 21:06:49+03:00         5  0.4  1.07  1.07      7  -59   57
#
#   humidity pm2_5_cf1 channel_id     lat     long
# 0       38         0     742703  0.2357  32.5576
# 1       38       0.2     742703  0.2357  32.5576
# 2       38       0.4     742703  0.2357  32.5576
# 3       38      0.47     742703  0.2357  32.5576
# 4       37      1.07     742703  0.2357  32.5576

# %%
#Combining all the data into one dataframe
combined_channel_data = pd.concat(channel_name_dict, join='outer', sort=False, ignore_index=True)
print (combined_channel_data.shape)
combined_channel_data.head()
# Out:
# (6860797, 17)
#                        time  entry_id     pm2_5      pm10  s2_pm2_5   s2_pm10  \
# 0 2018-12-05 14:17:49+03:00         1     11.97     18.11     24.15      1.39
# 1 2018-12-05 14:18:49+03:00         2      5.67      7.58      9.33      1.39
# 2 2018-12-05 14:19:47+03:00         3      4.83      6.29      7.15      1.39
# 3 2018-12-05 14:20:44+03:00         4      5.11      6.68      9.56      1.39
# 4 2018-12-05 14:21:44+03:00         5      4.91      6.44      8.59      1.39
#
#            lat         long   voltage gps_data channel_id  pm1 uptime RSSI  \
# 0     0.000000     0.000000      3.91     None     643676  NaN    NaN  NaN
# 1  1000.000000  1000.000000      3.93     None     643676  NaN    NaN  NaN
# 2  1000.000000  1000.000000      3.93     None     643676  NaN    NaN  NaN
# 3  1000.000000  1000.000000      3.94     None     643676  NaN    NaN  NaN
# 4  1000.000000  1000.000000      3.94     None     643676  NaN    NaN  NaN
#
#   temp humidity pm2_5_cf1
# 0  NaN      NaN       NaN
# 1  NaN      NaN       NaN
# 2  NaN      NaN       NaN
# 3  NaN      NaN       NaN
# 4  NaN      NaN       NaN

# %%
#Rearranging columns to make more sense
combined_channel_data = combined_channel_data[['time', 'channel_id','entry_id', 'pm1', 'pm2_5', 'pm10', 's2_pm2_5', 's2_pm10', 
                                               'lat', 'long', 'voltage', 'uptime', 'RSSI', 'temp', 'humidity', 
                                               'gps_data', 'pm2_5_cf1']]
# Out:
# (6860797, 17)

# %%
new = combined_channel_data['gps_data'].str.split(',')
combined_channel_data['altitude'] = new[2]
combined_channel_data['wind'] = new[3]
combined_channel_data['no_sats'] = new[4]
combined_channel_data['hdope'] = new[5]
combined_channel_data['temp'] = new[6]
combined_channel_data['humidity'] = new[7]

# %%
combined_channel_data=combined_channel_data.drop(['gps_data'], axis=1)

# %%
#Replacing latitude and longitude values of 0 and 1000 with Null
combined_channel_data['lat'] = combined_channel_data['lat'].replace([0.000000,1000.000000], np.nan)
combined_channel_data['long'] = combined_channel_data['long'].replace([0.000000,1000.000000], np.nan)
combined_channel_data.head()
# Out:
#                        time channel_id  entry_id  pm1     pm2_5      pm10  \
# 0 2018-12-05 14:17:49+03:00     643676         1  NaN     11.97     18.11
# 1 2018-12-05 14:18:49+03:00     643676         2  NaN      5.67      7.58
# 2 2018-12-05 14:19:47+03:00     643676         3  NaN      4.83      6.29
# 3 2018-12-05 14:20:44+03:00     643676         4  NaN      5.11      6.68
# 4 2018-12-05 14:21:44+03:00     643676         5  NaN      4.91      6.44
#
#    s2_pm2_5   s2_pm10          lat         long   voltage uptime RSSI  temp  \
# 0     24.15      1.39     0.000000     0.000000      3.91    NaN  NaN  None
# 1      9.33      1.39  1000.000000  1000.000000      3.93    NaN  NaN  None
# 2      7.15      1.39  1000.000000  1000.000000      3.93    NaN  NaN  None
# 3      9.56      1.39  1000.000000  1000.000000      3.94    NaN  NaN  None
# 4      8.59      1.39  1000.000000  1000.000000      3.94    NaN  NaN  None
#
#   humidity pm2_5_cf1 altitude  wind no_sats hdope
# 0     None       NaN     None  None    None  None
# 1     None       NaN     None  None    None  None
# 2     None       NaN     None  None    None  None
# 3     None       NaN     None  None    None  None
# 4     None       NaN     None  None    None  None

# %%
def db_connect(db_name,coll_name):
    client = MongoClient("mongodb://localhost:27017/")
    print('Connected successfully!')
    
    db=client[db_name]
    col=client[coll_name]

# %%
#Function that retrieves data from mongodb into a dataframe
def mongo2df(db_name,coll_name):
    db_connect(db_name,coll_name)
    
    df = pd.DataFrame(list(col.find()))
    return df

# %%
#importing data from dataframe to  MongoDb
def mongoimportdataframe(df, db_name, coll_name):
    db_connect(db_name,coll_name) 
    
    records = json.loads(df.T.to_json()).values()
    db.coll.insert_many(records)

# %%
def create_db(db_name):
    client = MongoClient("mongodb://localhost:27017/")
    print('Connected successfully!')
    db = client[db_name]

# %%
def create_collection(db_name,coll_name):
    db_connect(db_name,coll_name)

# %%
def insert_record(db_name, coll_name, mydict):
    db_connect(db_name,coll_name) 
    
    x = col.insert_one(mydict)
    return x

# %%
def update_collection(df, db_name, coll_name, key, data):
    db_connect(db_name,coll_name) 
    
    records = json.loads(df.T.to_json()).values()
    db.col.update(records, upsert=True)

# %%
def print_collection(db_name, coll_name):
    client = MongoClient("mongodb://localhost:27017/")
    print('Connected successfully!')
    db = client[db_name]
    col = db[coll_name]
    
    for x in db.col.find():
            print (x)

# %%
create_db('channel_db')
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'channel_db')

# %%
create_collection('channel_db','metadata_collection')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'channel_db'), 'metadata_collection')

# %%
create_collection('channel_db','channeldata_collection')
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'channel_db'), 'channeldata_collection')

# %%
mongoimportdataframe(channel_metadata, 'channel_db', 'metadata_collection')

# %%
mongoimportdataframe(combined_channel_data, 'channel_db', 'channeldata_collection')

# %%
print_collection('channel_db', 'metadata_collection')

# %%
print_collection('channel_db', 'channeldata_collection')
